# %% [markdown]
# <a class="anchor" id="chapter1"></a>
#
# # 1. Imports
#
# </a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <a class="anchor" id="chapter2"></a>
#
# # 2. Load Data
#
# </a>

# %%
occ = pd.read_csv("../Data/Job Descriptions/occupations_en.csv")
occrs = pd.read_csv("../Data/Job Descriptions/occupationSkillRelations_en.csv")
skills = pd.read_csv("../Data/Job Descriptions/skills_en.csv")

# %% [markdown]
# <a class="anchor" id="chapter3"></a>
#
# # 3. Initial Analysis
#
# </a>

# %% [markdown]
# <a class="anchor" id="sub-section-3_1"></a>
#
# ## 3.1. Occupations
#
# </a>

# %% [markdown]
# <a class="anchor" id="sub-section-3_1_1"></a>
#
# ### 3.1.1. Types & Structure
#
# </a>

# %%
print("Shape of Occupations df:", occ.shape)
occ.head()
# Out:
# Shape of Occupations df: (3043, 15)
#   conceptType                                         conceptUri  iscoGroup  \
# 0  Occupation  http://data.europa.eu/esco/occupation/00030d09...       2654
# 1  Occupation  http://data.europa.eu/esco/occupation/000e93a3...       8121
# 2  Occupation  http://data.europa.eu/esco/occupation/0019b951...       7543
# 3  Occupation  http://data.europa.eu/esco/occupation/0022f466...       3155
# 4  Occupation  http://data.europa.eu/esco/occupation/002da35b...       2431
#
#                    preferredLabel  \
# 0              technical director
# 1  metal drawing machine operator
# 2      precision device inspector
# 3   air traffic safety technician
# 4     hospitality revenue manager
#
#                                            altLabels hiddenLabels    status  \
# 0  director of technical arts\ntechnical supervis...          NaN  released
# 1  wire drawer\nforming machine operative\ndraw m...          NaN  released
# 2  precision device quality control supervisor\np...          NaN  released
# 3  air traffic safety electronics hardware specia...          NaN  released
# 4  yield manager\nhospitality yields manager\nhos...          NaN  released
#
#                modifiedDate  \
# 0  2024-01-25T11:28:50.295Z
# 1  2024-01-23T10:09:32.099Z
# 2  2024-01-25T15:00:12.188Z
# 3  2024-01-29T16:01:13.998Z
# 4  2024-01-11T10:28:45.871Z
#
#                              regulatedProfessionNote scopeNote definition  \
# 0  http://data.europa.eu/esco/regulated-professio...       NaN        NaN
# 1  http://data.europa.eu/esco/regulated-professio...       NaN        NaN
# 2  http://data.europa.eu/esco/regulated-professio...       NaN        NaN
# 3  http://data.europa.eu/esco/regulated-professio...       NaN        NaN
# 4  http://data.europa.eu/esco/regulated-professio...       NaN        NaN
#
#                                             inScheme  \
# 0  http://data.europa.eu/esco/concept-scheme/memb...
# 1  http://data.europa.eu/esco/concept-scheme/memb...
# 2  http://data.europa.eu/esco/concept-scheme/memb...
# 3  http://data.europa.eu/esco/concept-scheme/memb...
# 4  http://data.europa.eu/esco/concept-scheme/memb...
#
#                                          description       code  \
# 0  Technical directors realise the artistic visio...   2654.1.7
# 1  Metal drawing machine operators set up and ope...     8121.4
# 2  Precision device inspectors make sure precisio...  7543.10.3
# 3  Air traffic safety technicians provide technic...     3155.1
# 4  Hospitality revenue managers maximise revenue ...     2431.9
#
#                                             naceCode
# 0             http://data.europa.eu/ux2/nace2.1/9031
# 1              http://data.europa.eu/ux2/nace2.1/242
# 2             http://data.europa.eu/ux2/nace2.1/2651
# 3             http://data.europa.eu/ux2/nace2.1/5223
# 4  http://data.europa.eu/ux2/nace2.1/701,\nhttp:/...

# %%
occ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3043 entries, 0 to 3042
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   conceptType              3043 non-null   object
#  1   conceptUri               3043 non-null   object
#  2   iscoGroup                3043 non-null   int64
#  3   preferredLabel           3043 non-null   object
#  4   altLabels                3043 non-null   object
#  5   hiddenLabels             8 non-null      object
#  6   status                   3043 non-null   object
#  7   modifiedDate             3043 non-null   object
#  8   regulatedProfessionNote  3043 non-null   object
#  9   scopeNote                310 non-null    object
#  10  definition               8 non-null      object
#  11  inScheme                 3043 non-null   object
#  12  description              3043 non-null   object
#  13  code                     3043 non-null   object
#  14  naceCode                 3043 non-null   object
# dtypes: int64(1), object(14)
# memory usage: 356.7+ KB

# %% [markdown]
# <a class="anchor" id="sub-section-3_1_2"></a>
#
# ### 3.1.2. Duplicates
#
# </a>

# %%
occ[occ.index.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [conceptType, conceptUri, iscoGroup, preferredLabel, altLabels, hiddenLabels, status, modifiedDate, regulatedProfessionNote, scopeNote, definition, inScheme, description, code, naceCode]
# Index: []

# %%
duplicates = occ.duplicated().sum()
print(f"There are {duplicates} duplicated rows.")
# Out:
# There are 0 duplicated rows.

# %% [markdown]
# <a class="anchor" id="sub-section-3_1_3"></a>
#
# ### 3.1.3. Missing Values
#
# </a>

# %%
occ.isna().sum()
# Out:
# conceptType                   0
# conceptUri                    0
# iscoGroup                     0
# preferredLabel                0
# altLabels                     0
# hiddenLabels               3035
# status                        0
# modifiedDate                  0
# regulatedProfessionNote       0
# scopeNote                  2733
# definition                 3035
# inScheme                      0
# description                   0
# code                          0
# naceCode                      0
# dtype: int64

# %% [markdown]
# <a class="anchor" id="sub-section-3_1_4"></a>
#
# ### 3.1.4. Statistical Analysis
#
# </a>

# %%
occ.describe(include = object).T
# Out:
#                         count unique  \
# conceptType              3043      1
# conceptUri               3043   3039
# preferredLabel           3043   3039
# altLabels                3043   3039
# hiddenLabels                8      8
# status                   3043      1
# modifiedDate             3043   2902
# regulatedProfessionNote  3043      2
# scopeNote                 310    274
# definition                  8      8
# inScheme                 3043      2
# description              3043   3039
# code                     3043   3039
# naceCode                 3043   1121
#
#                                                                        top  \
# conceptType                                                     Occupation
# conceptUri               http://data.europa.eu/esco/occupation/4d27152a...
# preferredLabel                              early years teaching assistant
# altLabels                reception teaching assistant\nassistant in ear...
# hiddenLabels             sexual health consultant\nyouth policy manager...
# status                                                            released
# modifiedDate                                      2025-06-25T07:45:00.959Z
# regulatedProfessionNote  http://data.europa.eu/esco/regulated-professio...
# scopeNote                Excludes people performing managerial activities.
# definition                                          Excludes choreologist.
# inScheme                 http://data.europa.eu/esco/concept-scheme/memb...
# description              Early years teaching assistants support the ea...
# code                                                                5312.1
# naceCode                            http://data.europa.eu/ux2/nace2.1/9039
#
#                          freq
# conceptType              3043
# conceptUri                  2
# preferredLabel              2
# altLabels                   2
# hiddenLabels                1
# status                   3043
# modifiedDate               27
# regulatedProfessionNote  3027
# scopeNote                  12
# definition                  1
# inScheme                 2921
# description                 2
# code                        2
# naceCode                   50

# %% [markdown]
# <a class="anchor" id="sub-section-3_1_5"></a>
#
# ### 3.1.5. Drop Columns
#
# </a>

# %% [markdown]
# To construct the job descriptions, I will only need:
# - conceptUri: ESCO occupation ID
# - isoGroup:
# - preferredLabel: Job title
# - description: Job description text

# %%
print(list(occ))
# Out:
# ['conceptType', 'conceptUri', 'iscoGroup', 'preferredLabel', 'altLabels', 'hiddenLabels', 'status', 'modifiedDate', 'regulatedProfessionNote', 'scopeNote', 'definition', 'inScheme', 'description', 'code', 'naceCode']

# %%
occ = occ.drop(['conceptType', 'altLabels', 'hiddenLabels', 'status', 'modifiedDate', 
                'regulatedProfessionNote', 'scopeNote', 'definition', 'inScheme', 'code', 
                'naceCode'], axis=1)

# %% [markdown]
# <a class="anchor" id="sub-section-3_2"></a>
#
# ## 3.2. Occupation Skill Relations
#
# </a>

# %%
occ.head()
# Out:
#                                           conceptUri  iscoGroup  \
# 0  http://data.europa.eu/esco/occupation/00030d09...       2654
# 1  http://data.europa.eu/esco/occupation/000e93a3...       8121
# 2  http://data.europa.eu/esco/occupation/0019b951...       7543
# 3  http://data.europa.eu/esco/occupation/0022f466...       3155
# 4  http://data.europa.eu/esco/occupation/002da35b...       2431
#
#                    preferredLabel  \
# 0              technical director
# 1  metal drawing machine operator
# 2      precision device inspector
# 3   air traffic safety technician
# 4     hospitality revenue manager
#
#                                          description
# 0  Technical directors realise the artistic visio...
# 1  Metal drawing machine operators set up and ope...
# 2  Precision device inspectors make sure precisio...
# 3  Air traffic safety technicians provide technic...
# 4  Hospitality revenue managers maximise revenue ...

# %%
print("Length of Occupations Skillss Relations df:", len(occrs))
occrs.head()
# Out:
# Length of Occupations Skillss Relations df: 126051
#                                        occupationUri     occupationLabel  \
# 0  http://data.europa.eu/esco/occupation/00030d09...  technical director
# 1  http://data.europa.eu/esco/occupation/00030d09...  technical director
# 2  http://data.europa.eu/esco/occupation/00030d09...  technical director
# 3  http://data.europa.eu/esco/occupation/00030d09...  technical director
# 4  http://data.europa.eu/esco/occupation/00030d09...  technical director
#
#   relationType         skillType  \
# 0    essential         knowledge
# 1    essential  skill/competence
# 2    essential  skill/competence
# 3    essential  skill/competence
# 4    essential  skill/competence
#
#                                             skillUri  \
# 0  http://data.europa.eu/esco/skill/fed5b267-73fa...
# 1  http://data.europa.eu/esco/skill/05bc7677-5a64...
# 2  http://data.europa.eu/esco/skill/271a36a0-bc7a...
# 3  http://data.europa.eu/esco/skill/47ed1d37-971b...
# 4  http://data.europa.eu/esco/skill/591dd514-735b...
#
#                                           skillLabel
# 0                                 theatre techniques
# 1                                organise rehearsals
# 2  write risk assessment on performing arts produ...
# 3               coordinate with creative departments
# 4                 adapt to artists' creative demands

# %%
occrs['relationType'].describe()
# Out:
# count        126051
# unique            2
# top       essential
# freq          67600
# Name: relationType, dtype: object

# %%
essential_skills = occrs[occrs['relationType'] = 'essential']
# Out:
#   Cell In[27], line 1
#     essential_skills = occrs[occrs['relationType'] = 'essential']
#                              ^
# SyntaxError: cannot assign to subscript here. Maybe you meant '==' instead of '='?
